# %% [markdown]
# # 4. Bài tập

# %% [markdown]
# ## a. Code lại các ví dụ trong Phần 3

# %%
import pandas as pd

# %% [markdown]
# **Đọc dữ liệu và gán vào biến coronaData**

# %%
coronaData=pd.read_csv('./Data/covid_19_data.csv')
coronaData.shape[0]
# Out:
# 306429

# %% [markdown]
# **Liệt kê số cột trong bảng dữ liệu**

# %%
coronaData.shape[1]
# Out:
# 8

# %% [markdown]
# **Liệt kê số dòng**

# %%
coronaData.shape[0]
# Out:
# 306429

# %% [markdown]
# **In ra 10 dòng đầu trong bảng dữ liệu**

# %%
coronaData.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# ...

# %% [markdown]
# **In ra tên các biến (tên cột) của dữ liệu**

# %%
coronaData.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %% [markdown]
# **Tạo biến countryCorona lưu giá trị là các quốc gia có dịch Corona (Cột Country.Region)**

# %%
countryCorona=coronaData['Country/Region']	
countryCorona
# Out:
# 0         Mainland China
# 1         Mainland China
# 2         Mainland China
# 3         Mainland China
# 4         Mainland China
#                ...
# 306424           Ukraine
# 306425       Netherlands
# 306426    Mainland China
# 306427           Ukraine
# 306428       Netherlands
# Name: Country/Region, Length: 306429, dtype: object

# %% [markdown]
# **Liệt kê số lượng ca lây nhiễm được xác nhận (biến Confirmed) nhiều nhất và lưu vào biến maxConfirmedCases. Sử dụng lệnh max()**

# %%
maxConfirmedCases=coronaData.Confirmed.max()
maxConfirmedCases
# Out:
# 5863138.0

# %% [markdown]
# **Liệt kê các dữ liệu về covid-19 tại quốc gia Trung Quốc đại lục (Mainland China) và lưu vào biến coronaChina**

# %%
coronaChina=coronaData[coronaData['Country/Region']=='Mainland China']
coronaChina
# Out:
#            SNo ObservationDate Province/State  Country/Region  \
# 0            1      01/22/2020          Anhui  Mainland China
# 1            2      01/22/2020        Beijing  Mainland China
# 2            3      01/22/2020      Chongqing  Mainland China
# 3            4      01/22/2020         Fujian  Mainland China
# 4            5      01/22/2020          Gansu  Mainland China
# ...        ...             ...            ...             ...
# 306340  306341      05/29/2021          Tibet  Mainland China
# 306368  306369      05/29/2021        Unknown  Mainland China
# 306412  306413      05/29/2021       Xinjiang  Mainland China
# 306420  306421      05/29/2021         Yunnan  Mainland China
# 306426  306427      05/29/2021       Zhejiang  Mainland China
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# 1           1/22/2020 17:00       14.0     0.0        0.0
# ...

# %% [markdown]
# **Tìm quốc gia (Country.Region) có số ca lây nhiễm nhiều nhất**

# %%
print('Tổng số ca lây nhiễm nhiều nhất là ',int(coronaData['Confirmed'].max()),'ca')
print('Quốc gia có số ca lây nhiễm nhiều nhất là:',coronaData[coronaData['Confirmed']==coronaData['Confirmed'].max()]['Country/Region'].values)
# Out:
# Tổng số ca lây nhiễm nhiều nhất là  5863138 ca
# Quốc gia có số ca lây nhiễm nhiều nhất là: ['France']

# %% [markdown]
# **Tìm tỉnh (Province.State) có số ca lây nhiễm nhiều nhất**

# %%
print('Tổng số ca lây nhiễm nhiều nhất là ',int(coronaData['Confirmed'].max()),'ca')
print('Quốc gia có số ca lây nhiễm nhiều nhất là:',coronaData[coronaData['Confirmed']==coronaData['Confirmed'].max()]['Province/State'].values)
# Out:
# Tổng số ca lây nhiễm nhiều nhất là  5863138 ca
# Quốc gia có số ca lây nhiễm nhiều nhất là: [nan]

# %% [markdown]
# **Định dạng lại cột dữ liệu ngày tháng**

# %%
coronaData['ObservationDate']=pd.to_datetime(coronaData['ObservationDate'])
coronaData['ObservationDate']
# Out:
# 0        2020-01-22
# 1        2020-01-22
# 2        2020-01-22
# 3        2020-01-22
# 4        2020-01-22
#             ...
# 306424   2021-05-29
# 306425   2021-05-29
# 306426   2021-05-29
# 306427   2021-05-29
# 306428   2021-05-29
# Name: ObservationDate, Length: 306429, dtype: datetime64[ns]

# %% [markdown]
# **Lấy dữ liệu trong tháng 1/2020: bắt đầu từ 01/01/2020 đến 31/01/2020.**

# %%
coronaData[(coronaData['ObservationDate']>='2020-01-01')&(coronaData['ObservationDate']<='2020-01-31')]
# Out:
#      SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0      1      2020-01-22          Anhui  Mainland China  1/22/2020 17:00
# 1      2      2020-01-22        Beijing  Mainland China  1/22/2020 17:00
# 2      3      2020-01-22      Chongqing  Mainland China  1/22/2020 17:00
# 3      4      2020-01-22         Fujian  Mainland China  1/22/2020 17:00
# 4      5      2020-01-22          Gansu  Mainland China  1/22/2020 17:00
# ..   ...             ...            ...             ...              ...
# 508  509      2020-01-31            NaN     Philippines  1/31/2020 23:59
# 509  510      2020-01-31            NaN           India  1/31/2020 23:59
# 510  511      2020-01-31            NaN          Sweden  1/31/2020 23:59
# 511  512      2020-01-31        Unknown           China  1/31/2020 23:59
# 512  513      2020-01-31            NaN        Kiribati  1/31/2020 23:59
#
#      Confirmed  Deaths  Recovered
# 0          1.0     0.0        0.0
# ...

# %% [markdown]
# ## b.Tìm dữ liệu về số ca lây nhiễm tại Vietnam (Country.Region == 'Vietnam') và lưu vào biến coronaVietnam.

# %%
coronaVietnam=coronaData[coronaData["Country/Region"]=="Vietnam"]
coronaVietnam
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 81          82      2020-01-23            NaN        Vietnam
# 127        128      2020-01-24            NaN        Vietnam
# 170        171      2020-01-25            NaN        Vietnam
# 218        219      2020-01-26            NaN        Vietnam
# 267        268      2020-01-27            NaN        Vietnam
# ...        ...             ...            ...            ...
# 302771  302772      2021-05-25            NaN        Vietnam
# 303536  303537      2021-05-26            NaN        Vietnam
# 304301  304302      2021-05-27            NaN        Vietnam
# 305066  305067      2021-05-28            NaN        Vietnam
# 305831  305832      2021-05-29            NaN        Vietnam
#
#                 Last Update  Confirmed  Deaths  Recovered
# 81            1/23/20 17:00        2.0     0.0        0.0
# 127           1/24/20 17:00        2.0     0.0        0.0
# ...

# %% [markdown]
# ## c. Tìm dữ liệu về số ca lây nhiễm tại Việt Nam trong tháng 02 năm 2021.

# %%
coronaVietnam[coronaVietnam.ObservationDate.dt.month==2]
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 553        554      2020-02-01            NaN        Vietnam
# 622        623      2020-02-02            NaN        Vietnam
# 690        691      2020-02-03            NaN        Vietnam
# 760        761      2020-02-04            NaN        Vietnam
# 832        833      2020-02-05            NaN        Vietnam
# 905        906      2020-02-06            NaN        Vietnam
# 979        980      2020-02-07            NaN        Vietnam
# 1052      1053      2020-02-08            NaN        Vietnam
# 1126      1127      2020-02-09            NaN        Vietnam
# 1200      1201      2020-02-10            NaN        Vietnam
# 1274      1275      2020-02-11            NaN        Vietnam
# 1349      1350      2020-02-12            NaN        Vietnam
# 1424      1425      2020-02-13            NaN        Vietnam
# 1500      1501      2020-02-14            NaN        Vietnam
# ...

# %% [markdown]
# ## d. In ra số dữ liệu về ca lây nhiễm nhiều nhất trong khoảng tháng 01 và 02 tại Việt Nam (Lấy năm 2021).

# %%
def findMaxConfirmed(x:pd.DataFrame())->pd.DataFrame():
    startTime=pd.Timestamp(2021, 1, 1)
    endTime=pd.Timestamp(2021, 2, 28)
    return x[x.Confirmed==x[(x.ObservationDate >=startTime) & (x.ObservationDate<=endTime)]["Confirmed"].max()]

# %%
findMaxConfirmed(coronaVietnam)
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 236981  236982      2021-02-28            NaN        Vietnam
# 237746  237747      2021-03-01            NaN        Vietnam
#
#                 Last Update  Confirmed  Deaths  Recovered
# 236981  2021-04-02 15:13:53     2448.0    35.0     1876.0
# 237746  2021-04-02 15:13:53     2448.0    35.0     1876.0

# %% [markdown]
# ## e. Thực hiện tương tự câu d. cho Indonesia và Philipine.

# %%
coronaIndonesia=coronaData[coronaData["Country/Region"]=="Indonesia"]
findMaxConfirmed(coronaIndonesia)
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 236884  236885      2021-02-28            NaN      Indonesia
#
#                 Last Update  Confirmed   Deaths  Recovered
# 236884  2021-04-02 15:13:53  1334634.0  36166.0  1142703.0

# %%
coronaPhilipine=coronaData[coronaData["Country/Region"]=="Philippines"]
findMaxConfirmed(coronaPhilipine)
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 236936  236937      2021-02-28            NaN    Philippines
#
#                 Last Update  Confirmed   Deaths  Recovered
# 236936  2021-04-02 15:13:53   576352.0  12318.0   534271.0

# %% [markdown]
# ## e. In ra dữ liệu về ca nhiễm ghi nhân (Confirmed) của Trung Quốc trong khoảng thời gian từ 01/02/2021 cho đến 15/02/2021. In ra màn hình sử dụng lệnh print().

# %%
print(coronaChina[(pd.to_datetime(coronaChina['ObservationDate'])>="2021-02-01")&(pd.to_datetime(coronaChina['ObservationDate'])<="2021-02-15")][['ObservationDate','Confirmed']])
# Out:
#        ObservationDate  Confirmed
# 216353      02/01/2021      994.0
# 216387      02/01/2021     1039.0
# 216437      02/01/2021      591.0
# 216479      02/01/2021      541.0
# 216484      02/01/2021      187.0
# ...                ...        ...
# 227545      02/15/2021        1.0
# 227573      02/15/2021        0.0
# 227617      02/15/2021      980.0
# 227625      02/15/2021      231.0
# 227631      02/15/2021     1320.0
#
# [480 rows x 2 columns]

# %% [markdown]
# ## f. Thống kê số lượng record theo từng tỉnh của Trung Quốc trong tháng 02/2021.

# %%
ProvincesChina=coronaChina[(pd.to_datetime(coronaChina.ObservationDate).dt.month==2)&(pd.to_datetime(coronaChina.ObservationDate).dt.year==2021)].groupby('Province/State')
ProvincesChina.size()
# Out:
# Province/State
# Anhui             28
# Beijing           28
# Chongqing         28
# Fujian            28
# Gansu             28
# Guangdong         28
# Guangxi           28
# Guizhou           28
# Hainan            28
# Hebei             28
# Heilongjiang      28
# Henan             28
# Hubei             28
# Hunan             28
# Inner Mongolia    28
# Jiangsu           28
# Jiangxi           28
# Jilin             28
# Liaoning          28
# Ningxia           28
# Qinghai           28
# Shaanxi           28
# Shandong          28
# Shanghai          28
# Shanxi            28
# Sichuan           28
# Tianjin           28
# Tibet             28
# Unknown           28
# Xinjiang          28
# Yunnan            28
# Zhejiang          28
# dtype: int64

# %% [markdown]
# ## g. Đếm số lượng ca nhiễm theo từng tỉnh của Trung Quốc trong tháng 02/2021

# %%
ProvincesChina.max("Observation").Confirmed-ProvincesChina.min("Observation").Confirmed
# Out:
# Province/State
# Anhui              0.0
# Beijing           10.0
# Chongqing          0.0
# Fujian            10.0
# Gansu              0.0
# Guangdong         85.0
# Guangxi            0.0
# Guizhou            0.0
# Hainan             0.0
# Hebei              4.0
# Heilongjiang      19.0
# Henan              1.0
# Hubei              1.0
# Hunan              4.0
# Inner Mongolia     1.0
# Jiangsu            7.0
# Jiangxi            0.0
# Jilin             18.0
# Liaoning           4.0
# Ningxia            0.0
# Qinghai            0.0
# Shaanxi           11.0
# Shandong           3.0
# Shanghai          91.0
# Shanxi             1.0
# Sichuan           29.0
# Tianjin           12.0
# Tibet              0.0
# Unknown            1.0
# Xinjiang           0.0
# Yunnan             2.0
# Zhejiang           5.0
# Name: Confirmed, dtype: float64

# %% [markdown]
# ## h. Tìm dữ liệu ca tử vong của Trung Quốc trong khoảng thời gian từ 01/02/2021 cho đến 15/02/2021. In ra màn hình sử dụng lệnh print().

# %%
print(coronaChina[(pd.to_datetime(coronaChina['ObservationDate'])>="2021-02-01")&(pd.to_datetime(coronaChina['ObservationDate'])<="2021-02-15")][['ObservationDate','Deaths']])
# Out:
#        ObservationDate  Deaths
# 216353      02/01/2021     6.0
# 216387      02/01/2021     9.0
# 216437      02/01/2021     6.0
# 216479      02/01/2021     1.0
# 216484      02/01/2021     2.0
# ...                ...     ...
# 227545      02/15/2021     0.0
# 227573      02/15/2021     0.0
# 227617      02/15/2021     3.0
# 227625      02/15/2021     2.0
# 227631      02/15/2021     1.0
#
# [480 rows x 2 columns]

# %% [markdown]
# ## i. *Có nhận xét gì về số ca nhiễm mới tại Việt Nam giữa tháng 05/2020 và tháng 05/2021. Vẽ biểu đồ đường thể hiện số ca nhiễm mới trong 2 tháng trên.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Biểu đồ số ca nhiễm tại Việt Nam vào tháng 5/2020

# %%
y=coronaVietnam[(coronaVietnam.ObservationDate.dt.month==5)&(coronaVietnam.ObservationDate.dt.year==2020)]["Confirmed"]
x=coronaVietnam[(coronaVietnam.ObservationDate.dt.month==5)&(coronaVietnam.ObservationDate.dt.year==2020)]["ObservationDate"]


plt.figure(figsize=(12,6))
plt.plot(x,y)
plt.title("Số ca nhiễm tại Việt Nam vào tháng 5/2020")
plt.xlabel("Date")
plt.ylabel("Confirmed")
plt.show()

# %% [markdown]
# ### Biểu đồ số ca nhiễm tại Việt Nam vào tháng 5/2020

# %%
y=coronaVietnam[(coronaVietnam.ObservationDate.dt.month==5)&(coronaVietnam.ObservationDate.dt.year==2021)]["Confirmed"]
x=coronaVietnam[(coronaVietnam.ObservationDate.dt.month==5)&(coronaVietnam.ObservationDate.dt.year==2021)]["ObservationDate"]


plt.figure(figsize=(12,6))
plt.plot(x,y)
plt.title("Số ca nhiễm tại Việt Nam vào tháng 5/2021")
plt.xlabel("Date")
plt.ylabel("Confirmed")
plt.show()

# %% [markdown]
# **Nhận xét: Tha thấy số ca nhiễm mới của Việt Nam ngày cang tăng mạnh theo thời gian ở năm 2020 ta thấy số ca mới theo ngày tăng rất ít chỉ vài chục nhưng đến năm 2021 ta thấy số ca nhiễm mới mỗi ngày tăng vài trăm ca**

# %% [markdown]
# ## k.Vẽ biểu đồ về số ca lây nhiễm nhiều nhất của 3 quốc gia: Vietnam, Indonesia và Philippine trong 2 tháng gồm 01 và tháng 02 năm 2021.

# %% [markdown]
# ### Lọc dữ liệu và thêm cột month để vẽ đồ thị

# %%
import seaborn as sns
filtered_data=coronaData[(coronaData.ObservationDate.dt.month.isin([1,2]))&(coronaData.ObservationDate.dt.year==2021)&(coronaData["Country/Region"].isin(["Vietnam","Indonesia","Philippines"]))].groupby(["Country/Region",pd.Grouper(key='ObservationDate', freq='M')],as_index=False).max("Confirmed")
filtered_data['Month']=filtered_data.ObservationDate.dt.month.astype(str)
filtered_data
# Out:
#   Country/Region ObservationDate     SNo  Confirmed   Deaths  Recovered Month
# 0      Indonesia      2021-01-31  215465  1078314.0  29998.0   873221.0     1
# 1      Indonesia      2021-02-28  236885  1334634.0  36166.0  1142703.0     2
# 2    Philippines      2021-01-31  215517   525618.0  10749.0   487551.0     1
# 3    Philippines      2021-02-28  236937   576352.0  12318.0   534271.0     2
# 4        Vietnam      2021-01-31  215562     1817.0     35.0     1457.0     1
# 5        Vietnam      2021-02-28  236982     2448.0     35.0     1876.0     2

# %% [markdown]
# ### Vẽ đồ thị

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=filtered_data,x="Confirmed",y="Month",hue="Country/Region")
plt.title("Số ca nhiễm tối đa của 3 quốc gia vào tháng 1 và 2 năm 2021")
plt.xlabel("Số ca nhiễm tối đa")
plt.ylabel("Tháng")
plt.xscale('log')
plt.show()
# Out:
# c:\Users\phamd\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\phamd\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\phamd\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
